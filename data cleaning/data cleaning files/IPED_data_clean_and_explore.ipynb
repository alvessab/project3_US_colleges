# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Import documents

# %%
df = pd.read_csv("../data/IPEDs 2020 data.csv")

df.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
# ...

# %%
values = pd.read_csv("../data/IPEDS value dictionary.csv")
values.head()
# Out:
#    varnumber varname codevalue  valuelabel frequency  percent
# 0      10016  STABBR        AL     Alabama        81     1.26
# 1      10016  STABBR        AK      Alaska        10     0.16
# 2      10016  STABBR        AZ     Arizona       116     1.80
# 3      10016  STABBR        AR    Arkansas        86     1.34
# 4      10016  STABBR        CA  California       700    10.87

# %% [markdown]
# ## Keep Some Columns

# %%
#drop deathyr and closed at
mask = df2.DEATHYR == -2
df3 = df2.loc[mask]
df3.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  OPEFLAG  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President        1
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President        1
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President        1
# 3  Huntsville     AL       35899           Darren Dawson  President        1
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President        1
#
# ...

# %%
#drop deathyr and closed at
df4 = df3[["INSTNM", "ADDR", "CITY", "STABBR", "ZIP", "CHFNM", "CHFTITLE", "OPEFLAG", "WEBADDR",
         "ADMINURL", "FAIDURL", "APPLURL","NPRICURL", "VETURL", "ATHURL", "DISAURL", "SECTOR",
         "HLOFFER", "DEGGRANT", "HBCU", "HOSPITAL", "MEDICAL", "TRIBAL", "LOCALE", "OPENPUBL",
          "INSTCAT", "C18IPUG", "C18UGPRF", "C18ENPRF", "C18SZSET", "CCBASIC",
         "LONGITUD", "LATITUDE"]]
df4.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  OPEFLAG  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President        1
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President        1
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President        1
# 3  Huntsville     AL       35899           Darren Dawson  President        1
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President        1
#
# ...

# %% [markdown]
# ## Rename Variables

# %%
#opeflag
mask = values.varname == "OPEFLAG"
opeflag_val = values.loc[mask]
opeflag_val
# Out:
#      varnumber  varname codevalue  \
# 128      10076  OPEFLAG         1
# 129      10076  OPEFLAG         2
# 130      10076  OPEFLAG         3
# 131      10076  OPEFLAG         8
# 132      10076  OPEFLAG         5
# 133      10076  OPEFLAG         6
# 134      10076  OPEFLAG         7
#
#                                             valuelabel frequency  percent
# 128  Participates in Title IV federal financial aid...     6,126    95.12
# 129  Branch campus of a main campus that participat...        90     1.40
# 130             Deferment only - limited participation        26     0.40
# 131  New participants (became eligible during sprin...         1     0.02
# 132  Not currently participating in Title IV, has a...       163     2.53
# 133  Not currently participating in Title IV, does ...        31     0.48
# 134       Stopped participating during the survey year         3     0.05

# %%
code_val_rep = [int(x) for x in opeflag_val.codevalue]
label_val = list(opeflag_val.valuelabel)

# %%
df5 = df4.copy()
df5.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  OPEFLAG  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President        1
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President        1
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President        1
# 3  Huntsville     AL       35899           Darren Dawson  President        1
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President        1
#
# ...

# %%
df5['OPEFLAG'] = df5['OPEFLAG'].replace(code_val_rep,label_val)
df5.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#SECTOR
mask = values.varname == "SECTOR"
sector_val = values.loc[mask]
sector_val
# Out:
#      varnumber varname codevalue                                valuelabel  \
# 135      10086  SECTOR         0                       Administrative Unit
# 136      10086  SECTOR         1                   Public, 4-year or above
# 137      10086  SECTOR         2   Private not-for-profit, 4-year or above
# 138      10086  SECTOR         3       Private for-profit, 4-year or above
# 139      10086  SECTOR         4                            Public, 2-year
# 140      10086  SECTOR         5            Private not-for-profit, 2-year
# 141      10086  SECTOR         6                Private for-profit, 2-year
# 142      10086  SECTOR         7                  Public, less-than 2-year
# 143      10086  SECTOR         8  Private not-for-profit, less-than 2-year
# 144      10086  SECTOR         9      Private for-profit, less-than 2-year
# 145      10086  SECTOR        99               Sector unknown (not active)
#
#     frequency  percent
# 135        72     1.12
# ...

# %%
code_val_rep = [int(x) for x in sector_val.codevalue]
label_val = list(sector_val.valuelabel)

# %%
df6 = df5.copy()
df6.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
df6['SECTOR'] = df6['SECTOR'].replace(code_val_rep,label_val)
df6.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#HLOFFER
mask = values.varname == "HLOFFER"
hloffer_val = values.loc[mask]

code_val_rep = [int(x) for x in hloffer_val.codevalue]
label_val = list(hloffer_val.valuelabel)

df7 = df6.copy()

df7['HLOFFER'] = df7['HLOFFER'].replace(code_val_rep,label_val)
df7.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#DEGGRANT
mask = values.varname == "DEGGRANT"
deggrant_val = values.loc[mask]

code_val_rep = [int(x) for x in deggrant_val.codevalue]
label_val = list(deggrant_val.valuelabel)

df8 = df7.copy()

df8['DEGGRANT'] = df8['DEGGRANT'].replace(code_val_rep,label_val)
df8.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#HBCU
mask = values.varname == "HBCU"
hbcu_val = values.loc[mask]

code_val_rep = [int(x) for x in hbcu_val.codevalue]
label_val = list(hbcu_val.valuelabel)

df9 = df8.copy()

df9['HBCU'] = df9['HBCU'].replace(code_val_rep,label_val)
df9.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#HOSPITAL
mask = values.varname == "HOSPITAL"
hospital_val = values.loc[mask]

code_val_rep = [int(x) for x in hospital_val.codevalue]
label_val = list(hospital_val.valuelabel)

df10 = df9.copy()

df10['HOSPITAL'] = df10['HOSPITAL'].replace(code_val_rep,label_val)
df10.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#MEDICAL
mask = values.varname == "MEDICAL"
medical_val = values.loc[mask]

code_val_rep = [int(x) for x in medical_val.codevalue]
label_val = list(medical_val.valuelabel)

df11 = df10.copy()

df11['MEDICAL'] = df11['MEDICAL'].replace(code_val_rep,label_val)
df11.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#TRIBAL
mask = values.varname == "TRIBAL"
tribal_val = values.loc[mask]

code_val_rep = [int(x) for x in tribal_val.codevalue]
label_val = list(tribal_val.valuelabel)

df12 = df11.copy()

df12['TRIBAL'] = df12['TRIBAL'].replace(code_val_rep,label_val)
df12.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#LOCALE
mask = values.varname == "LOCALE"
locale_val = values.loc[mask]

code_val_rep = [int(x) for x in locale_val.codevalue]
label_val = list(locale_val.valuelabel)

df13 = df12.copy()

df13['LOCALE'] = df13['LOCALE'].replace(code_val_rep,label_val)
df13.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#OPENPUBL
mask = values.varname == "OPENPUBL"
openpubl_val = values.loc[mask]

code_val_rep = [int(x) for x in openpubl_val.codevalue]
label_val = list(openpubl_val.valuelabel)

df14 = df13.copy()

df14['OPENPUBL'] = df14['OPENPUBL'].replace(code_val_rep,label_val)
df14.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#INSTCAT
mask = values.varname == "INSTCAT"
instacat_val = values.loc[mask]

code_val_rep = [int(x) for x in instacat_val.codevalue]
label_val = list(instacat_val.valuelabel)

df15 = df14.copy()

df15['INSTCAT'] = df15['INSTCAT'].replace(code_val_rep,label_val)
df15.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#C18IPUG
mask = values.varname == "C18IPUG"
C18IPUG_val = values.loc[mask]

code_val_rep = [int(x) for x in C18IPUG_val.codevalue]
label_val = list(C18IPUG_val.valuelabel)

df16 = df15.copy()

df16['C18IPUG'] = df16['C18IPUG'].replace(code_val_rep,label_val)
df16.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#C18UGPRF
mask = values.varname == "C18UGPRF"
C18UGPRF_val = values.loc[mask]

code_val_rep = [int(x) for x in C18UGPRF_val.codevalue]
label_val = list(C18UGPRF_val.valuelabel)

df17 = df16.copy()

df17['C18UGPRF'] = df17['C18UGPRF'].replace(code_val_rep,label_val)
df17.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#C18SZSET
mask = values.varname == "C18SZSET"
C18SZSET_val = values.loc[mask]

code_val_rep = [int(x) for x in C18SZSET_val.codevalue]
label_val = list(C18SZSET_val.valuelabel)

df18 = df17.copy()

df18['C18SZSET'] = df18['C18SZSET'].replace(code_val_rep,label_val)
df18.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#C18ENPRF
mask = values.varname == "C18ENPRF"
C18ENPRF_val = values.loc[mask]

code_val_rep = [int(x) for x in C18ENPRF_val.codevalue]
label_val = list(C18ENPRF_val.valuelabel)

df19 = df18.copy()

df19['C18ENPRF'] = df19['C18ENPRF'].replace(code_val_rep,label_val)
df19.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %%
#CCBASIC
mask = values.varname == "CCBASIC"
CCBASIC_val = values.loc[mask]

code_val_rep = [int(x) for x in CCBASIC_val.codevalue]
label_val = list(CCBASIC_val.valuelabel)

df20 = df19.copy()

df20['CCBASIC'] = df20['CCBASIC'].replace(code_val_rep,label_val)
df20.head()
# Out:
#                                 INSTNM                            ADDR  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY STABBR         ZIP                   CHFNM   CHFTITLE  \
# 0      Normal     AL       35762  Dr. Andrew Hugine, Jr.  President
# 1  Birmingham     AL  35294-0110            Ray L. Watts  President
# 2  Montgomery     AL  36117-3553        Michael C.Turner  President
# 3  Huntsville     AL       35899           Darren Dawson  President
# 4  Montgomery     AL  36104-0271         Quinton T. Ross  President
#
#                                                    OPEFLAG  \
# 0  Participates in Title IV federal financial aid programs
# ...

# %% [markdown]
# ## Rename Columns

# %%
df21 = df20.copy()
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6356 entries, 0 to 6439
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   INSTNM    6356 non-null   object
#  1   ADDR      6355 non-null   object
#  2   CITY      6356 non-null   object
#  3   STABBR    6356 non-null   object
#  4   ZIP       6356 non-null   object
#  5   CHFNM     6356 non-null   object
#  6   CHFTITLE  6356 non-null   object
#  7   OPEFLAG   6356 non-null   object
#  8   WEBADDR   6356 non-null   object
#  9   ADMINURL  6356 non-null   object
#  10  FAIDURL   6356 non-null   object
#  11  APPLURL   6356 non-null   object
#  12  NPRICURL  6356 non-null   object
#  13  VETURL    6356 non-null   object
#  14  ATHURL    6356 non-null   object
#  15  DISAURL   6356 non-null   object
#  16  SECTOR    6356 non-null   object
#  17  HLOFFER   6356 non-null   object
#  18  DEGGRANT  6356 non-null   object
#  19  HBCU      6356 non-null   object
# ...

# %%
df21 = df21.rename(columns= {"INSTNM": "Institution",
                            "ADDR": "Address",
                            "STABBR": "State",
                            "CHFNM": "Chief Administrator",
                            "CHFTITLE": "Chief Administrator Title",
                            "OPEFLAG": "Eligibility For Title IV Aid",
                            "WEBADDR": "Web Address",
                            "ADMINURL": "Admissions",
                            "FAIDURL": "Financial Aid",
                            "APPLURL": "Apply URL",
                            "NPRICURL": "Net Price Calculator",
                            "VETURL": "Veteran's URL",
                            "ATHURL": "Athlete's URL",
                            "DISAURL": "Disabilities Services",
                            "SECTOR": "Sector",
                            "HLOFFER": "Highest Level of Offering",
                            "DEGGRANT": "Degree Granting Status",
                            "HOSPITAL": "Hospital Available",
                            "MEDICAL": "Medical Degree Granting",
                            "OPENPUBL": "Open for Admission to the General Public",
                            "INSTCAT": "Degree Level Offered",
                            "C18IPUG": "Undergraduate Instructional Program Classification",
                             "C18UGPRF": "Undergraduate Profile Classification",
                             "C18ENPRF": "Enrollment Profile Classification",
                             "C18SZSET": "Size and Setting Classification",
                             "CCBASIC": "Basic Classification",
                             "LONGITUD": "Longitude",
                             "LATITUDE": "Latitude",
                             "TRIBAL": "Tribal",
                             "LOCALE": "Locale"
                            })

df21.head()
# Out:
#                            Institution                         Address  \
# 0             Alabama A & M University            4900 Meridian Street
# 1  University of Alabama at Birmingham  Administration Bldg Suite 1070
# 2                   Amridge University                  1200 Taylor Rd
# 3  University of Alabama in Huntsville                 301 Sparkman Dr
# 4             Alabama State University            915 S Jackson Street
#
#          CITY State         ZIP     Chief Administrator  \
# 0      Normal    AL       35762  Dr. Andrew Hugine, Jr.
# 1  Birmingham    AL  35294-0110            Ray L. Watts
# 2  Montgomery    AL  36117-3553        Michael C.Turner
# 3  Huntsville    AL       35899           Darren Dawson
# 4  Montgomery    AL  36104-0271         Quinton T. Ross
#
#   Chief Administrator Title  \
# 0                 President
# 1                 President
# 2                 President
# 3                 President
# 4                 President
#
# ...

# %%
mask = values.varname == "HLOFFER"
C18UGPRF_val = values.loc[mask]
C18UGPRF_val
# Out:
#      varnumber  varname codevalue                                valuelabel  \
# 154      10101  HLOFFER         1      Award of less than one academic year
# 155      10101  HLOFFER         2  At least 1, but less than 2 academic yrs
# 156      10101  HLOFFER         3                        Associate's degree
# 157      10101  HLOFFER         4  At least 2, but less than 4 academic yrs
# 158      10101  HLOFFER         5                         Bachelor's degree
# 159      10101  HLOFFER         6             Postbaccalaureate certificate
# 160      10101  HLOFFER         7                           Master's degree
# 161      10101  HLOFFER         8                 Post-master's certificate
# 162      10101  HLOFFER         9                           Doctor's degree
# 163      10101  HLOFFER        -3                           {Not available}
#
#     frequency  percent
# 154       176     2.73
# 155     1,629    25.30
# 156     1,110    17.24
# 157       575     8.93
# ...

# %%
mask = df21["Medical Degree Granting"] == "Yes"
df21.loc[mask]
# Out:
#                                                Institution  \
# 1                      University of Alabama at Birmingham
# 10                                       Auburn University
# 48                             University of South Alabama
# 54                                     Tuskegee University
# 76                                   University of Arizona
# ...                                                    ...
# 6220  Texas Tech University Health Sciences Center-El Paso
# 6276                 Idaho College of Osteopathic Medicine
# 6349                Hackensack Meridian School of Medicine
# 6393                     The Pennsylvania State University
# 6414         California University of Science and Medicine
#
#                              Address             CITY State         ZIP  \
# 1     Administration Bldg Suite 1070       Birmingham    AL  35294-0110
# 10                                             Auburn    AL       36849
# ...

# %% [markdown]
# ## Import to Data Folder

# %%
df21.to_csv("../../static/data/IPEDs.csv",index=False)

# %%
df21.to_html("../../static/data/IPEDs.html",index=False)
